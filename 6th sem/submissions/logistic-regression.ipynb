# %%
import pandas as pd
import numpy as np
# Out:
# Running cells with 'Python 3.10.0 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'C:/Users/hp/AppData/Local/Programs/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
df = pd.read_csv('../input/2022-ucs654-Lab-2-Exam/h1-train_data.csv')

# %%
X_train = train_dataset.iloc[:,1:51]

# %%
Y_train = train_dataset.iloc[:,51:52]

# %%
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression()

# %%
logreg.fit(X_train, Y_train)

# %%
df1 = pd.read_csv('../input/2022-ucs654-Lab-2-Exam/h1-test_data.csv')

# %%
X_test = df1.iloc[:,1:51]
X_test.head()

# %%
y_test0 = df1.iloc[:,0:1]
y_test1 = logreg.predict(X_test)
y_test2 = pd.DataFrame(y_test1,columns = ['target'])

# %%
final_df = pd.concat([y_test0,y_test2], axis=1)

# %%
final_df.head()

# %%
final_df.to_csv('sub_log_reg.csv',index=False)
